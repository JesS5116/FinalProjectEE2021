# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse
import missingno as msno
import seaborn as sns
from scipy.stats import linregress

# %%
# Lectura de archivos
esolmet = pd.read_csv('../data/EsolmetRuoaTo.csv',index_col=0,parse_dates=True)
una     = pd.read_csv('../data/junio_dos_Ti.csv',index_col=0,parse_dates=True)
# concat
data = pd.concat([esolmet,una],axis=1)
data.dropna(inplace=True)
data
# Out:
#                         To     TCAire    Ti_0001     Ti_001      Ti_01  \
# tiempo
# 2019-06-08 00:00:00  19.81  25.348056  25.361544  24.684068  22.231431
# 2019-06-08 00:10:00  19.87  25.311138  25.316520  24.637702  22.228500
# 2019-06-08 00:20:00  19.89  25.274220  25.271685  24.595729  22.218035
# 2019-06-08 00:30:00  19.95  25.228072  25.229249  24.560534  22.221022
# 2019-06-08 00:40:00  19.95  25.187692  25.183962  24.522077  22.204529
# ...                    ...        ...        ...        ...        ...
# 2019-06-23 23:00:00  23.97  26.680580  26.889922  26.722965  25.887151
# 2019-06-23 23:10:00  23.59  26.614819  26.825575  26.664331  25.854572
# 2019-06-23 23:20:00  23.39  26.729035  26.750191  26.576357  25.671825
# 2019-06-23 23:30:00  23.33  26.567517  26.678062  26.467406  25.430992
# 2019-06-23 23:40:00  23.49  26.530599  26.636620  26.428766  25.446335
#
#                         Ti_003
# tiempo
# 2019-06-08 00:00:00  23.765785
# 2019-06-08 00:10:00  23.729572
# 2019-06-08 00:20:00  23.697010
# 2019-06-08 00:30:00  23.672572
# 2019-06-08 00:40:00  23.639542
# ...                        ...
# 2019-06-23 23:00:00  26.483282
# 2019-06-23 23:10:00  26.433264
# 2019-06-23 23:20:00  26.319706
# 2019-06-23 23:30:00  26.145427
# 2019-06-23 23:40:00  26.111662
#
# [858 rows x 6 columns]

# %% [markdown]
# ## Regresión lineal

# %%
def linear_regression(data,caso,c):
    # Para el caso Ti_ae
    Ti_s = caso
    
    fig, ax = plt.subplots(figsize=(6,6))
    
    
    x = np.linspace(-10,10,2)
    y = x 
    
    X = np.array( data.To-data.To.mean()   )
    Y = np.array( Ti_s-data.To.mean() )
    m,b,r_value, p_value,std_err = linregress(X,Y)
    
    ax.scatter(X,Y)
    ax.plot(x,y,'k-') 
    ax.plot(x,x*m+b,'r-') 
    
    
    ax.set_xlim(-10,10)
    ax.set_ylim(-10,10)
    ax.set_box_aspect(1)
    ax.set_ylabel('Ti_s [oC]')
    ax.set_xlabel('Ti   [oC]')
    ax.set_title(f'Regresión lineal de caso c={c}kg/s')
    ax.grid()
    print(m,b,r_value)

# %%
linear_regression(data,data.Ti_0001,'0.001')
# Out:
# 0.629651575655468 3.3664309431726482 0.9315962481128265

# %%
linear_regression(data,data.Ti_001,'0.01')
# Out:
# 0.6477548813448938 3.0489577967944292 0.9433910138554245

# %%
linear_regression(data,data.Ti_01,'0.1')
# Out:
# 0.7885235134829349 1.9739247325151879 0.9698712575306734

# %%
linear_regression(data,data.Ti_003,'0.03')
# Out:
# 0.7071375726351167 2.734612826182407 0.951866570795353

# %% [markdown]
# ## Relación de Pearson

# %%
data[['Ti_0001', 'Ti_001', 'Ti_01', 'Ti_003','TCAire']].corr()
# Out:
#           Ti_0001    Ti_001     Ti_01    Ti_003    TCAire
# Ti_0001  1.000000  0.998658  0.983784  0.995163  0.664430
# Ti_001   0.998658  1.000000  0.990711  0.998430  0.674434
# Ti_01    0.983784  0.990711  1.000000  0.996107  0.677533
# Ti_003   0.995163  0.998430  0.996107  1.000000  0.667837
# TCAire   0.664430  0.674434  0.677533  0.667837  1.000000

# %%
nombres = ['Ti_0001', 'Ti_001', 'Ti_01', 'Ti_003','TCAire']
for i in nombres:
    print(i,data.TCAire.corr(data[i]))
# Out:
# Ti_0001 0.6644300905434606
# Ti_001 0.6744343575105533
# Ti_01 0.6775334099077214
# Ti_003 0.6678374029069224
# TCAire 1.0

# %% [markdown]
# ## dRMSE

# %%
for i in nombres:
    print(i,((data[i] - data.TCAire)**2).mean()**.5)
# Out:
# Ti_0001 2.974818127912914
# Ti_001 2.749969422243381
# Ti_01 2.490514820121982
# Ti_003 2.6816038384679683
# TCAire 0.0

# %% [markdown]
# ## Diferencia promedio de Ti

# %%
for i in nombres:
    print(i,(data[i]-data.TCAire).mean())
# Out:
# Ti_0001 2.1696852066905237
# Ti_001 1.8522120603123047
# Ti_01 0.7771789960330612
# Ti_003 1.537867089700283
# TCAire 0.0

# %% [markdown]
# ## Diferencia promedio de las temperaturas máximas/mínimas diarias

# %%
for i in nombres:
    print(i,(data[i].resample("1D").max() - data.TCAire.resample("1D").max()).mean())
# Out:
# Ti_0001 4.132980406155991
# Ti_001 3.8520981531551786
# Ti_01 3.4060932592783164
# Ti_003 3.7940316598895425
# TCAire 0.0

# %%
for i in nombres:
    print(i,(data[i].resample("1D").min() - data.TCAire.resample("1D").min()).mean())
# Out:
# Ti_0001 0.8651588503036708
# Ti_001 0.39921479962277456
# Ti_01 -1.6604877470966244
# Ti_003 -0.31761373055639375
# TCAire 0.0

# %% [markdown]
# ## Diferencia promedio del FD

# %%
for i in nombres:
    df_s = (data[i].resample("1D").max() - data[i].resample("1D").min()) / (data.To.resample("1D").max() - data.To.resample("1D").min())
    df_e = (data.TCAire.resample("1D").max() - data.TCAire.resample("1D").min()) / (data.To.resample("1D").max() - data.To.resample("1D").min())

    print(i,(df_s - df_e).mean())
# Out:
# Ti_0001 0.29613312229553623
# Ti_001 0.311235588508743
# Ti_01 0.4477104071000113
# Ti_003 0.366704990581582
# TCAire 0.0
