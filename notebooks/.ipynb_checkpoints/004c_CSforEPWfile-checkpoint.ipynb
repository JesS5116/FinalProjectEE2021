# %%
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse
import numpy as np

# %%
# Leo archivo de datos limpios
data = pd.read_csv('../data/splitdata.csv')
data.drop('tiempo',axis='columns',inplace=True)
data
# Out:
#       year  month  day  hour  minute  Idirecta  Iglobal  Idifusa     UV  \
# 0     2019      3    5     0       0     0.000    0.000      0.0  0.186
# 1     2019      3    5     0      10     0.000    0.000      0.0  0.183
# 2     2019      3    5     0      20     0.000    0.000      0.0  0.184
# 3     2019      3    5     0      30     0.000    0.000      0.0  0.183
# 4     2019      3    5     0      40     0.000    0.000      0.0  0.185
# ...    ...    ...  ...   ...     ...       ...      ...      ...    ...
# 7628  2019      6   24    23      20     0.132    0.000      0.0  0.000
# 7629  2019      6   24    23      30     0.150    0.000      0.0  0.000
# 7630  2019      6   24    23      40     0.112    0.000      0.0  0.000
# 7631  2019      6   24    23      50     0.155    0.000      0.0  0.000
# 7632  2019      6   25     0       0     0.012    0.184      0.0  0.000
#
#          To     HR  Wspeed   Presion
# 0     23.02  47.67   3.463  876.0016
# ...

# %%
data.to_csv('../data/dataforepw.csv',index=False,header=False)
