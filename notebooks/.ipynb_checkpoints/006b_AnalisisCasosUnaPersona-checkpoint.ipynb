# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse
import missingno as msno
import seaborn as sns

# %%
# Datos de mediciones de fin de semana
weekend_data = pd.read_csv('../data/weekends.csv',index_col=0,parse_dates=True)
weekend_data = weekend_data.resample("600S").interpolate(method='time')
#weekend_data

# %%
# Nombres de e+ siempre los mismos
nombres = np.genfromtxt('../idf/cubiculo_original/UnaPersona/c001/c001.csv',
                        dtype='U',delimiter=',',max_rows=1,)
nombres

for i,nombre in enumerate(nombres):
    print(i,nombre)
# Out:
# 0 Date/Time
# 1 THERMAL ZONE: JORGE:Zone Mean Air Temperature [C](TimeStep)
# 2 JORGE:Zone Thermal Comfort Fanger Model PMV [](TimeStep)
# 3 JORGE:Zone Thermal Comfort Fanger Model PPD [%](TimeStep)

# %%
# funcion para importar datos de e+
def importa(file,caso):
    nombres = ['tiempo',f'Ti_{caso}',f'PMV_{caso}',f'PPD_{caso}']
    simulate = pd.read_csv(file,names=nombres,skiprows=1)
    simulate.tiempo = simulate.tiempo.str.replace('24:00:00','23:59:59')
    simulate.tiempo = '2019-'+simulate.tiempo
    simulate.tiempo = pd.to_datetime(simulate.tiempo,format='%Y- %m/%d %H:%M:%S')
    simulate.tiempo = simulate.tiempo-pd.Timedelta('10minute')
    simulate.set_index('tiempo',inplace=True)
    # Hago columna de dias para hacer mascara (opcional)
    #simulate['dia'] = simulate.index.day_of_week
    # solo dines de semana de simulaciones
    weekend_simu = simulate[simulate.index.day_of_week>=5]
    return weekend_simu

# %%
c0001 = importa('../idf/cubiculo_original/UnaPersona/c0001/c0001.csv','0001')
c001  = importa('../idf/cubiculo_original/UnaPersona/c001/c001.csv','001')
c01   = importa('../idf/cubiculo_original/UnaPersona/c01/c01.csv','01')
c003 = importa('../idf/cubiculo_original/UnaPersona/c003/c003.csv','003')

# %%
data = pd.concat([weekend_data,c0001,c001,c01,c003],axis=1)
data
# Out:
#                         TCAire    Ti_0001   PMV_0001  PPD_0001     Ti_001  \
# tiempo
# 2019-05-04 00:00:00        NaN  27.360737 -27.759822     100.0  27.132711
# 2019-05-04 00:10:00        NaN  27.284559 -28.004428     100.0  27.137958
# 2019-05-04 00:20:00        NaN  27.204034 -28.226639     100.0  27.053100
# 2019-05-04 00:30:00        NaN  27.124539 -28.469371     100.0  26.914531
# 2019-05-04 00:40:00        NaN  27.072237 -28.625227     100.0  26.854061
# ...                        ...        ...        ...       ...        ...
# 2019-07-28 23:10:00  25.432277        NaN        NaN       NaN        NaN
# 2019-07-28 23:20:00  24.818508        NaN        NaN       NaN        NaN
# 2019-07-28 23:30:00  24.905036        NaN        NaN       NaN        NaN
# 2019-07-28 23:40:00  25.021559        NaN        NaN       NaN        NaN
# 2019-07-28 23:50:00  24.572770        NaN        NaN       NaN        NaN
#
#                        PMV_001  PPD_001      Ti_01     PMV_01  PPD_01  \
# tiempo
# 2019-05-04 00:00:00 -29.475697    100.0  26.399772 -31.105965   100.0
# 2019-05-04 00:10:00 -29.569007    100.0  26.519594 -30.965686   100.0
# 2019-05-04 00:20:00 -29.781703    100.0  26.266457 -31.448266   100.0
# 2019-05-04 00:30:00 -30.109640    100.0  25.962463 -32.056083   100.0
# 2019-05-04 00:40:00 -30.268674    100.0  25.959743 -32.132857   100.0
# ...                        ...      ...        ...        ...     ...
# 2019-07-28 23:10:00        NaN      NaN        NaN        NaN     NaN
# 2019-07-28 23:20:00        NaN      NaN        NaN        NaN     NaN
# 2019-07-28 23:30:00        NaN      NaN        NaN        NaN     NaN
# 2019-07-28 23:40:00        NaN      NaN        NaN        NaN     NaN
# 2019-07-28 23:50:00        NaN      NaN        NaN        NaN     NaN
#
#                         Ti_003    PMV_003  PPD_003
# tiempo
# 2019-05-04 00:00:00  26.832198 -30.162086    100.0
# 2019-05-04 00:10:00  26.923786 -30.092801    100.0
# 2019-05-04 00:20:00  26.800703 -30.357623    100.0
# 2019-05-04 00:30:00  26.564894 -30.842012    100.0
# 2019-05-04 00:40:00  26.508874 -30.993160    100.0
# ...                        ...        ...      ...
# 2019-07-28 23:10:00        NaN        NaN      NaN
# 2019-07-28 23:20:00        NaN        NaN      NaN
# 2019-07-28 23:30:00        NaN        NaN      NaN
# 2019-07-28 23:40:00        NaN        NaN      NaN
# 2019-07-28 23:50:00        NaN        NaN      NaN
#
# [8790 rows x 13 columns]

# %%
fig, ax = plt.subplots(figsize=(12,4))

fecha1 = parse('2019-06-08')
fecha2 = fecha1 + pd.Timedelta('2D')

ax.set_xlim(fecha1,fecha2)
ax.scatter(data.index,data.TCAire,marker='.',label='Medición')
ax.scatter(data.index,data.Ti_0001,marker='.',label='Simulación con c=0.001')
ax.scatter(data.index,data.Ti_001,marker='.',label='Simulación con c=0.01')
ax.scatter(data.index,data.Ti_01,marker='.',label='Simulación con c=0.1')
ax.scatter(data.index,data.Ti_003,marker='.',label='Simulación con c=0.03')
ax.set_title('Fin de semana 2019-06-08 para validación')
ax.legend()
ax.grid()

# %%
fig, ax = plt.subplots(figsize=(12,4))

fecha1 = parse('2019-06-15')
fecha2 = fecha1 + pd.Timedelta('2D')

ax.set_xlim(fecha1,fecha2)
ax.scatter(data.index,data.TCAire,marker='.',label='Medición')
ax.scatter(data.index,data.Ti_0001,marker='.',label='Simulación con c=0.001')
ax.scatter(data.index,data.Ti_001,marker='.',label='Simulación con c=0.01')
ax.scatter(data.index,data.Ti_01,marker='.',label='Simulación con c=0.1')
ax.scatter(data.index,data.Ti_003,marker='.',label='Simulación con c=0.03')
ax.set_title('Fin de semana 2019-06-15 para validación')
ax.legend()
ax.grid()

# %%
fig, ax = plt.subplots(figsize=(12,4))

fecha1 = parse('2019-06-22')
fecha2 = fecha1 + pd.Timedelta('2D')

ax.set_xlim(fecha1,fecha2)
ax.scatter(data.index,data.TCAire,marker='.',label='Medición')
ax.scatter(data.index,data.Ti_0001,marker='.',label='Simulación con c=0.001')
ax.scatter(data.index,data.Ti_001,marker='.',label='Simulación con c=0.01')
ax.scatter(data.index,data.Ti_01,marker='.',label='Simulación con c=0.1')
ax.scatter(data.index,data.Ti_003,marker='.',label='Simulación con c=0.03')
ax.set_title('Fin de semana 2019-06-22 para validación')
ax.legend()
ax.grid()
