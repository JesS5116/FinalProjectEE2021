# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse
import missingno as msno
import seaborn as sns
from scipy.stats import linregress

# %%
# Lectura de archivos
esolmet = pd.read_csv('../data/EsolmetRuoaTo.csv',index_col=0,parse_dates=True)
una     = pd.read_csv('../data/junio_una_Ti.csv',index_col=0,parse_dates=True)
# concat
data = pd.concat([esolmet,una],axis=1)
data.dropna(inplace=True)
data
# Out:
#                         To     TCAire    Ti_0001     Ti_001      Ti_01  \
# tiempo
# 2019-06-08 00:00:00  19.81  25.348056  25.345033  24.684068  22.224439
# 2019-06-08 00:10:00  19.87  25.311138  25.300062  24.637702  22.221660
# 2019-06-08 00:20:00  19.89  25.274220  25.255151  24.595729  22.211365
# 2019-06-08 00:30:00  19.95  25.228072  25.212782  24.560534  22.214526
# 2019-06-08 00:40:00  19.95  25.187692  25.167794  24.522077  22.198194
# ...                    ...        ...        ...        ...        ...
# 2019-06-23 23:00:00  23.97  26.680580  26.865181  26.722965  25.873201
# 2019-06-23 23:10:00  23.59  26.614819  26.801363  26.664331  25.839942
# 2019-06-23 23:20:00  23.39  26.729035  26.726535  26.576357  25.657603
# 2019-06-23 23:30:00  23.33  26.567517  26.654963  26.467406  25.417972
# 2019-06-23 23:40:00  23.49  26.530599  26.613995  26.428766  25.433132
#
#                         Ti_003
# tiempo
# 2019-06-08 00:00:00  23.753834
# 2019-06-08 00:10:00  23.717822
# 2019-06-08 00:20:00  23.685393
# 2019-06-08 00:30:00  23.661167
# 2019-06-08 00:40:00  23.628402
# ...                        ...
# 2019-06-23 23:00:00  26.463463
# 2019-06-23 23:10:00  26.413820
# 2019-06-23 23:20:00  26.300905
# 2019-06-23 23:30:00  26.127855
# 2019-06-23 23:40:00  26.094806
#
# [858 rows x 6 columns]

# %% [markdown]
# ## Regresión lineal

# %%
def linear_regression(data,caso,c):
    # Para el caso Ti_ae
    Ti_s = caso
    
    fig, ax = plt.subplots(figsize=(6,6))
    
    
    x = np.linspace(-10,10,2)
    y = x 
    
    X = np.array( data.To-data.To.mean()   )
    Y = np.array( Ti_s-data.To.mean() )
    m,b,r_value, p_value,std_err = linregress(X,Y)
    
    ax.scatter(X,Y)
    ax.plot(x,y,'k-') 
    ax.plot(x,x*m+b,'r-') 
    
    
    ax.set_xlim(-10,10)
    ax.set_ylim(-10,10)
    ax.set_box_aspect(1)
    ax.set_ylabel('Ti_s [oC]')
    ax.set_xlabel('Ti   [oC]')
    ax.set_title(f'Regresión lineal de caso c={c}kg/s')
    ax.grid()
    print(m,b,r_value)

# %%
linear_regression(data,data.Ti_0001,'0.001')
# Out:
# 0.6177534612162305 3.2826826917927536 0.9347847745980871

# %%
linear_regression(data,data.Ti_001,'0.01')
# Out:
# 0.6477548813448938 3.0489577967944292 0.9433910138554245

# %%
linear_regression(data,data.Ti_01,'0.1')
# Out:
# 0.7796072758106262 1.910560472105665 0.972032458165349

# %%
linear_regression(data,data.Ti_003,'0.03')
# Out:
# 0.6962113399817131 2.660334242802717 0.9544480734371785

# %% [markdown]
# ## Relación de Pearson

# %%
data[['Ti_0001', 'Ti_001', 'Ti_01', 'Ti_003','TCAire']].corr()
# Out:
#           Ti_0001    Ti_001     Ti_01    Ti_003    TCAire
# Ti_0001  1.000000  0.999107  0.983487  0.995055  0.674295
# Ti_001   0.999107  1.000000  0.989785  0.998304  0.674434
# Ti_01    0.983487  0.989785  1.000000  0.996001  0.684242
# Ti_003   0.995055  0.998304  0.996001  1.000000  0.676220
# TCAire   0.674295  0.674434  0.684242  0.676220  1.000000

# %%
nombres = ['Ti_0001', 'Ti_001', 'Ti_01', 'Ti_003','TCAire']
for i in nombres:
    print(i,data.TCAire.corr(data[i]))
# Out:
# Ti_0001 0.6742946862119965
# Ti_001 0.6744343575105533
# Ti_01 0.6842424726788037
# Ti_003 0.6762197476248768
# TCAire 1.0

# %% [markdown]
# ## dRMSE

# %%
for i in nombres:
    print(i,((data[i] - data.TCAire)**2).mean()**.5)
# Out:
# Ti_0001 2.8701628293557877
# Ti_001 2.749969422243381
# Ti_01 2.421927680745395
# Ti_003 2.5897810174933102
# TCAire 0.0

# %% [markdown]
# ## Diferencia promedio de Ti

# %%
for i in nombres:
    print(i,(data[i]-data.TCAire).mean())
# Out:
# Ti_0001 2.0859369553106317
# Ti_001 1.8522120603123047
# Ti_01 0.7138147356235394
# Ti_003 1.4635885063205902
# TCAire 0.0

# %% [markdown]
# ## Diferencia promedio de las temperaturas máximas/mínimas diarias

# %%
for i in nombres:
    print(i,(data[i].resample("1D").max() - data.TCAire.resample("1D").max()).mean())
# Out:
# Ti_0001 3.9765225016124126
# Ti_001 3.8520981531551786
# Ti_01 3.2741125102268795
# Ti_003 3.656580220982498
# TCAire 0.0

# %%
for i in nombres:
    print(i,(data[i].resample("1D").min() - data.TCAire.resample("1D").min()).mean())
# Out:
# Ti_0001 0.8559785332301928
# Ti_001 0.39921479962277456
# Ti_01 -1.6650985398895564
# Ti_003 -0.3242458632185663
# TCAire 0.0

# %% [markdown]
# ## Diferencia promedio del FD

# %%
for i in nombres:
    df_s = (data[i].resample("1D").max() - data[i].resample("1D").min()) / (data.To.resample("1D").max() - data.To.resample("1D").min())
    df_e = (data.TCAire.resample("1D").max() - data.TCAire.resample("1D").min()) / (data.To.resample("1D").max() - data.To.resample("1D").min())

    print(i,(df_s - df_e).mean())
# Out:
# Ti_0001 0.28314943676943855
# Ti_001 0.311235588508743
# Ti_01 0.4364029256822517
# Ti_003 0.3551924676682326
# TCAire 0.0
