# %%
import pandas as pd
import numpy as np

# %%
# Call file
data = pd.read_csv('../002_datos/esolmetruoasplit.csv')
data.drop('tiempo',axis='columns',inplace=True)
data
# Out:
#       year  month  day  hour  minute  Idirecta  Iglobal  Idifusa     To  \
# 0     2019      5    3     0       0     0.000    0.000      0.0  23.02
# 1     2019      5    3     0      10     0.000    0.000      0.0  22.95
# 2     2019      5    3     0      20     0.000    0.000      0.0  23.01
# 3     2019      5    3     0      30     0.000    0.000      0.0  22.83
# 4     2019      5    3     0      40     0.000    0.000      0.0  22.69
# ...    ...    ...  ...   ...     ...       ...      ...      ...    ...
# 7628  2019      6   24    23      20     0.132    0.000      0.0  23.52
# 7629  2019      6   24    23      30     0.150    0.000      0.0  23.54
# 7630  2019      6   24    23      40     0.112    0.000      0.0  23.39
# 7631  2019      6   24    23      50     0.155    0.000      0.0  23.16
# 7632  2019      6   25     0       0     0.012    0.184      0.0  22.48
#
#          HR     ws      wd         P
# 0     47.67  2.157   56.42  87600.16
# ...

# %%
data.to_csv('../epw/esolmetruoa/esolmetruoa.csv',header=False,index=False)

# %%
len(data.year)
# Out:
# 7633
